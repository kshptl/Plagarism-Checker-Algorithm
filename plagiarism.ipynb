# %% [markdown]
# # Project 1: MinHash and finding similar items
#
# ## Part 1: Jaccard Similarity and Shingles

# %%
# this piece of code is here to help wiht development using python module `plagiarism_lib`
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# The `plagiarism_lib` module includes a function to shingle documents. Here is an example of how to use it:

# %%
import plagiarism_lib.article_db as art_db

shingles = art_db._shingle_text('The cat in the hat', 2)
print(shingles)
# Out:
# {'th', 'nt', 'eh', 'ca', 'ha', 'in', 'ti', 'at', 'he', 'ec'}

# %% [markdown]
# Use this function to answer the following questions

# %%
# question 1: What is the jaccard similarity of these two sentences using 2-shingles:
s1 = "I would drink black tea"
s2 = "I would drink green tea"

sh1 = art_db._shingle_text(s1, 2)
sh2 = art_db._shingle_text(s2, 2)

len(sh1.intersection(sh2)) / len(sh1.union(sh2))
# Out:
# 0.4782608695652174

# %%
# question 2: What is the jaccard similarity of these two sentences using 2-shingles:
s1 = "I would drink green tea but I would not drink black tea"
s2 = "I would not drink green tea but I would drink black tea"

shingleLength = 7

sh1 = art_db._shingle_text(s1, shingleLength)
sh2 = art_db._shingle_text(s2, shingleLength)

len(sh1.intersection(sh2)) / len(sh1.union(sh2))
# Out:
# 0.8974358974358975

# %%
# question 3, what is the smallest shingle length we need to use 
# to distinguish these two sentences

# %% [markdown]
# ## Fetch data
#
# Run the following piece of code to fetch data to use in the project, and to setup experiment code

# %%
import plagiarism_lib.fetch_data as fetch
import plagiarism_lib.jaccard_experiment as jaccard_exp

import pandas as pd

# %%
# fetch small dataset from data repository
DATA_PATH = 'data'

fetch.fetch_data(path=DATA_PATH, maxsize=1000)

# %%
DATA_PATH = 'data'
train_file = DATA_PATH + '/articles_1000.train'
truth_file = DATA_PATH + '/articles_1000.truth'

import os

RESDIR_PATH = 'result_data'
if not os.path.isdir(RESDIR_PATH):
    os.mkdir(RESDIR_PATH)
    
jaccard_exp_csv = RESDIR_PATH + '/jaccard_exp_res.csv'

# %% [markdown]
# ## Jaccard similarity
#
# **TODO** Finish implementing the function `plagiarism_lib.jaccard._jaccard_similarity` to compute the Jaccard Similarity of two sets.
#
# Once you do that run the next chunk to perform an experiment on the effect of shard-length $k$ on Jaccard similarity of
# plagiarism instances versus instances that are not plagiarized.
#
# Make sure you set `RUN_JACCARD_EXP = True` to get your experiment data

# %%
# run this if needed
RUN_JACCARD_EXP = False
if RUN_JACCARD_EXP:
    exp_res = jaccard_exp.run_experiment(train_file, truth_file)
    exp_res.to_csv(jaccard_exp_csv, index=False)
else:
    exp_res = pd.read_csv(jaccard_exp_csv)

# %% [markdown]
# The following code makes a plot with $k$ in the x-axis and average Jaccard similarity in the y-axis with two lines:
# one for plagiarism instances, one for instances that are not plagiarism.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

# start here just to make plot
plot_df = exp_res.melt(id_vars=['k'])

fig, ax = plt.subplots()
labels = []

for key, grp in plot_df.groupby('variable'):
    ax = grp.plot(ax=ax, kind='line', x='k', y='value')
    labels.append(key)
lines, _ = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
plt.show()

# The plagarized instances show a significantly high jaccard similarity even with increasing shard-lengths.
# The jaccard similarity for non-plagaizrd instances quickly drops to 0 after the first inital shard-lengths.
# The initally high jaccard similarity of the non-plagaized instances could ba result of similar sentence structure or writing stye.

# %% [markdown]
# **TODO**: Comment on what you observe from this experiment.

# %% [markdown]
# ## Part 2: MinHash and Jaccard Similarity
#
# Load article data, preprocess it and shingle articles with length $k=10$

# %%
from plagiarism_lib.article_db import ArticleDB

artdb = ArticleDB(train_file)
exp_data = artdb.shingle_data(k=10)

# %% [markdown]
# Compute Jaccard similarities for pairs of articles in corpus. Set `RUN_MAKE_JS_DF=True` to prepare data on Jaccard similarity for our experiment.

# %%
import plagiarism_lib.minhash_experiment as minhash_exp
import pandas as pd

js_csv_file = RESDIR_PATH + '/js_df.csv'

# Switch True/False to run as needed
RUN_MAKE_JS_DF = False

if RUN_MAKE_JS_DF:
    exp_df = minhash_exp.make_js_df(exp_data, artdb._docids)
    exp_df.to_csv(js_csv_file, index=False)
else:
    exp_df = pd.read_csv(js_csv_file)

# %% [markdown]
# **TODO**: Finish implementing function `plagiarism_lib.minhash._make_minhash_sigmatrix` to construct the minhash signature matrix of the document collection.
#
# **TODO**: Finish implementing function `plagiarism_lib.minhash.MinHash.get_similarity` to compute the minhash estimate of Jaccard similarity given two minhash signatures.

# %% [markdown]
# Once you have completed the above todos, let's compute minhash similarity matrices with varying number of hash functions and compute Jaccard similarity estimates. Set `RUN_MAKE_MH_DF=True` and run the following chunk.

# %%
mh_csv_file = RESDIR_PATH + '/mh_df.csv'

hash_vals = [1]#[10, 20, 50]#, 100, 1000]
RUN_MAKE_MH_DF = True
if RUN_MAKE_MH_DF:
    minhash_exp.run(exp_data, exp_df, hash_vals=hash_vals)
    None#exp_df.to_csv(mh_csv_file, index=False)
else:
    exp_df = pd.read_csv(mh_csv_file)
# Out:
# Doing minhash for  1  hashes
# 4294964839 t7998
# array([[7.00229900e+06, 2.27415800e+06, 4.84403000e+05, 1.76327840e+07,
#         1.19006510e+07, 6.14110600e+06, 1.89757000e+05, 9.63525000e+05,
#         9.37489200e+06, 8.08051000e+05, 2.28145100e+06, 4.46762500e+06,
#         6.04876500e+06, 1.66064100e+06, 4.13329800e+06, 8.15042100e+06,
#         2.79841700e+06, 3.25547400e+06, 1.03795420e+07, 4.88375000e+05,
#         1.52385900e+06, 4.05732200e+06, 2.76757410e+07, 3.64734000e+06,
#         4.09598600e+06, 5.71348000e+06, 1.16706740e+07, 6.16187000e+05,
#         9.73632000e+05, 9.76130000e+05, 6.74733000e+06, 4.20403900e+06,
#         9.31488400e+06, 5.49304000e+05, 8.06122000e+05, 2.45927400e+06,
#         7.62576000e+06, 1.81188400e+06, 2.40782900e+06, 4.65816800e+06,
#         5.49552500e+06, 1.18634530e+07, 3.73656100e+06, 1.29888700e+06,
#         5.95375500e+06, 1.76374900e+06, 2.58980000e+05, 1.21731160e+07,
#         4.89523400e+06, 6.71483400e+06, 1.84039280e+07, 7.46515000e+05,
#         2.00983300e+06, 4.49260000e+05, 2.40197300e+06, 1.84881300e+06,
#         2.66508700e+06, 4.01752200e+06, 6.51693800e+06, 4.20639000e+05,
#         2.27213900e+06, 1.20388640e+07, 2.57433000e+06, 5.18510700e+06,
#         1.16770900e+06, 3.26835700e+06, 5.84413000e+05, 5.75012200e+06,
#         9.21702000e+05, 1.50049700e+06, 3.97584200e+06, 2.08699100e+06,
#         1.40892700e+06, 1.29812400e+06, 8.95507000e+06, 7.09175600e+06,
#         1.03372910e+07, 5.37724400e+06, 1.74044700e+06, 1.94581200e+06,
#         3.04090900e+06, 4.53318400e+06, 3.37806000e+05, 9.69087000e+06,
#         2.49744500e+06, 5.18640000e+05, 2.24114300e+06, 9.30485100e+06,
#         1.37882000e+07, 1.43577000e+06, 7.69024500e+06, 1.40045800e+06,
#         1.27363000e+06, 5.83486200e+06, 3.56712900e+06, 9.10043000e+06,
#         3.39877700e+06, 1.34948090e+07, 8.26510000e+05, 5.68642400e+06,
#         5.35545000e+05, 1.37361000e+05, 5.23821000e+05, 1.00276959e+09,
#         8.97572600e+06, 1.51048910e+07, 1.15311910e+07, 9.71293300e+06,
#         4.93221600e+06, 4.25615600e+06, 1.90742000e+05, 1.43045160e+07,
#         2.96079700e+06, 3.41300000e+04, 1.10672200e+06, 4.18641300e+06,
#         1.51452700e+06, 2.01830200e+06, 6.91608000e+05, 5.47678400e+06,
#         7.18076700e+06, 6.76014200e+06, 4.09248600e+06, 7.44364500e+06,
#         9.16652400e+06, 1.45154000e+05, 8.97100000e+05, 7.58674000e+05,
#         4.06695000e+05, 1.11379700e+06, 4.08260000e+04, 2.45377800e+06,
#         5.11633500e+06, 2.13079000e+06, 1.35887500e+06, 2.64528600e+06,
#         8.48859000e+05, 1.27068610e+07, 3.37460200e+06, 4.72441500e+06,
#         2.55830700e+06, 4.66715600e+06, 8.97450000e+04, 3.90312900e+06,
#         2.91445700e+06, 1.15878000e+05, 5.97994000e+05, 2.21612200e+06,
#         1.02616630e+07, 2.33275900e+06, 1.44172650e+07, 1.93864000e+06,
#         2.33743600e+06, 1.19062160e+07, 3.04017100e+06, 1.60694700e+06,
#         3.67890600e+06, 2.73900000e+04, 1.26533210e+07, 2.74142200e+06,
#         1.11636000e+05, 1.65745800e+06, 1.06844900e+06, 1.99844900e+06,
#         3.34012800e+06, 1.52994200e+06, 3.09661100e+06, 9.33790000e+04,
#         1.77073000e+06, 3.07349500e+06, 2.99473100e+06, 2.55425000e+05,
#         6.06969000e+06, 2.85009300e+06, 1.95152800e+06, 8.35340800e+06,
#         3.08826700e+06, 4.33857500e+06, 9.75894000e+05, 2.32170400e+06,
#         5.22912000e+06, 3.40843800e+06, 1.49154410e+07, 2.44430700e+06,
#         1.74139100e+06, 7.24372000e+05, 5.87106100e+06, 5.85082600e+06,
#         6.95709000e+05, 1.35636500e+06, 1.32010590e+07, 6.61924900e+06,
#         2.26005500e+06, 6.88580000e+04, 3.85647900e+06, 5.69103400e+06,
#         1.82744000e+05, 3.19770800e+06, 7.35351000e+05, 7.19670000e+05,
#         1.09568000e+06, 2.78795400e+06, 3.05040000e+04, 7.26406000e+05,
#         1.13205240e+07, 9.47182000e+05, 2.98651300e+06, 1.67085000e+07,
#         1.13574800e+07, 2.93308400e+06, 6.62239400e+06, 1.66732500e+06,
#         6.10030000e+04, 1.78093800e+06, 1.85222000e+06, 3.12666000e+06,
#         3.99382500e+06, 3.09865600e+06, 7.44841100e+06, 1.20792000e+05,
#         3.22002200e+06, 5.86555400e+06, 5.47032400e+06, 2.91737000e+05,
#         1.33746200e+06, 1.23621100e+06, 2.32540000e+05, 1.87962700e+06,
#         1.08300280e+07, 3.98314200e+06, 4.16298600e+06, 1.06597700e+07,
#         4.81099300e+06, 1.43982400e+06, 2.19613200e+06, 5.64454600e+06,
#         4.64192300e+06, 1.79195320e+07, 5.91078000e+06, 2.11958600e+06,
#         2.44947900e+06, 3.21814700e+06, 1.07581600e+06, 1.72160400e+06,
#         1.48931000e+06, 1.87468500e+06, 5.20234000e+06, 1.21849300e+06,
#         7.52437000e+05, 2.08413800e+06, 4.80556100e+06, 2.23254400e+06,
#         1.75133400e+06, 1.14339770e+07, 1.22938300e+06, 1.35687480e+07,
#         3.12636400e+06, 1.23234430e+07, 2.43966000e+06, 1.11066390e+07,
#         1.28766720e+07, 5.87726700e+06, 5.09870000e+06, 2.49607100e+06,
#         8.23058400e+06, 3.36701100e+06, 2.46371900e+06, 1.02212900e+06,
#         1.20221700e+06, 7.67286500e+06, 1.38669300e+06, 6.74711800e+06,
#         2.21960000e+04, 2.24987600e+06, 4.30850100e+06, 2.75603200e+06,
#         1.09456370e+07, 1.70638400e+06, 1.65549000e+06, 1.46250000e+06,
#         5.22704000e+05, 8.94140800e+06, 4.63143400e+06, 6.97983300e+06,
#         1.02620350e+07, 4.12268500e+06, 9.84250000e+05, 6.97051000e+05,
#         9.55232700e+06, 1.23759200e+06, 6.71765500e+06, 3.62102560e+07,
#         3.03141500e+06, 4.69923200e+06, 4.38467600e+06, 9.33463100e+06,
#         1.39872550e+07, 3.14237000e+05, 2.33263800e+06, 5.70321800e+06,
#         4.30929500e+06, 9.53323700e+06, 1.02029960e+07, 1.28330100e+06,
#         9.16560500e+06, 8.02511000e+05, 7.59692000e+05, 2.83540600e+06,
#         4.94371100e+06, 3.68550000e+04, 1.04332700e+06, 2.60029900e+06,
#         1.92339000e+06, 4.69712000e+05, 5.41973800e+06, 6.05749000e+05,
#         2.06797100e+06, 7.95123200e+06, 6.59412600e+06, 3.06761000e+05,
#         3.45655700e+06, 2.54625100e+06, 8.84252700e+06, 2.92985100e+06,
#         2.50056000e+06, 4.07270500e+06, 5.43918000e+05, 5.77050300e+06,
#         7.26944800e+06, 1.72981500e+06, 3.89958200e+06, 7.06707500e+06,
#         2.57877100e+06, 1.69014100e+06, 5.06561400e+06, 6.43425100e+06,
#         4.43316100e+06, 2.09124500e+06, 9.90155000e+05, 2.53439700e+06,
#         1.02651210e+07, 6.99252500e+06, 9.04986600e+06, 3.57614000e+06,
#         2.29125560e+07, 3.33514800e+06, 1.63644620e+07, 2.02973900e+06,
#         5.97133400e+06, 5.94414400e+06, 3.54739000e+05, 4.88000800e+06,
#         1.62722000e+06, 1.39802000e+06, 1.10130600e+06, 2.74582300e+06,
#         5.80167100e+06, 1.14752500e+06, 2.12425620e+07, 1.49466200e+06,
#         2.81120000e+04, 3.00210000e+06, 4.75710000e+04, 9.83255500e+06,
#         1.79738300e+06, 4.13680500e+06, 5.56170300e+06, 9.32243000e+05,
#         7.34444200e+06, 6.32605000e+05, 8.79550000e+04, 1.77702000e+05,
#         7.81664600e+06, 2.01514104e+08, 3.08721900e+06, 2.19755000e+06,
#         6.47974000e+06, 3.96238400e+06, 1.05784000e+07, 9.57190000e+04,
#         6.46446400e+06, 5.33637200e+06, 3.77371600e+06, 4.14130000e+05,
#         8.72971900e+06, 7.36061000e+05, 5.96502000e+05, 6.46897000e+05,
#         3.70452100e+06, 2.26944100e+06, 1.78178200e+06, 3.55780800e+06,
#         1.10494000e+05, 5.78278400e+06, 8.63808600e+06, 1.22731990e+07,
#         2.29394900e+06, 1.82645000e+05, 1.49504600e+07, 3.91034300e+06,
#         6.26630900e+06, 5.14126500e+06, 3.60037000e+05, 3.74274100e+06,
#         1.24751660e+07, 2.26881600e+06, 2.62083300e+06, 8.05695700e+06,
#         7.23822500e+06, 6.28105000e+05, 8.93801500e+06, 1.10162700e+06,
#         6.74516000e+05, 1.09375820e+07, 1.16629240e+07, 7.05632000e+05,
#         3.13923500e+06, 6.62099700e+06, 8.84611600e+06, 1.22702900e+06,
#         1.74416200e+06, 1.97018200e+06, 1.30834570e+07, 2.29949500e+06,
#         2.80088500e+06, 5.03081700e+06, 9.60678000e+05, 2.72646900e+06,
#         2.55042000e+06, 4.36525600e+06, 1.01530660e+07, 4.84544600e+06,
#         4.10801000e+06, 1.40428500e+06, 2.09758200e+06, 3.95523800e+06,
#         1.31515000e+05, 1.03501820e+07, 7.61842400e+06, 3.15873000e+06,
#         1.25525000e+05, 5.46243500e+06, 2.64000400e+06, 2.46296500e+06,
#         1.37818000e+06, 1.02165560e+07, 2.46112600e+06, 3.43537000e+05,
#         1.82793300e+06, 7.94849700e+06, 1.60372270e+07, 1.78583600e+06,
#         6.69150700e+06, 3.78602300e+06, 2.68946000e+05, 2.75921700e+06,
#         1.52153000e+06, 1.00939000e+06, 2.31147200e+06, 5.63195200e+06,
#         9.21805700e+06, 1.65507800e+06, 1.03174600e+06, 1.00896100e+06,
#         3.98664000e+05, 7.94719400e+06, 1.20712880e+07, 2.29557740e+07,
#         4.98936600e+06, 7.92865600e+06, 2.13996500e+06, 5.91333100e+06,
#         1.66950600e+06, 4.83079600e+06, 1.82831900e+06, 1.98340490e+07,
#         7.94489900e+06, 2.38565100e+06, 2.01930200e+06, 1.16902190e+07,
#         9.66533930e+07, 3.65698300e+06, 5.32479000e+05, 4.40128700e+06,
#         3.31102600e+06, 1.07702700e+06, 8.73817400e+06, 1.42548200e+06,
#         2.36686600e+06, 3.43008200e+06, 2.21063800e+06, 3.76259900e+06,
#         2.25958000e+06, 7.82381100e+06, 3.25190000e+04, 1.19118090e+07,
#         1.92690870e+07, 3.79421800e+06, 4.46020700e+06, 1.86559370e+07,
#         1.09316400e+06, 9.19452700e+06, 3.08533200e+06, 2.65076100e+06,
#         1.27476900e+06, 3.93879300e+06, 1.74812000e+05, 7.53873100e+06,
#         6.82255000e+06, 1.25960000e+04, 2.77534000e+05, 5.38450000e+05,
#         2.26993500e+06, 5.21066000e+05, 1.10301190e+07, 1.04753400e+06,
#         1.76176000e+06, 9.98691000e+05, 8.68566000e+05, 5.01543400e+06,
#         6.54765000e+05, 1.30904040e+07, 1.22398900e+07, 5.94286120e+08,
#         3.84188000e+05, 5.31664000e+05, 7.19194000e+05, 9.04327000e+05,
#         1.64698970e+07, 2.21283800e+06, 1.27289100e+06, 4.30153500e+06,
#         8.17462300e+06, 1.33346400e+06, 7.36616900e+06, 2.31640200e+06,
#         3.69367600e+06, 3.40558700e+06, 7.45319900e+06, 5.16938700e+06,
#         6.01983500e+06, 4.31022200e+06, 3.06196800e+06, 3.62417000e+05,
#         2.75398133e+08, 1.10789780e+07, 1.60216500e+06, 1.25236200e+06,
#         1.04479420e+07, 4.66731000e+06, 2.66640000e+06, 1.56810600e+06,
#         1.31791000e+06, 9.90872000e+05, 3.88800000e+03, 1.24131810e+07,
#         2.15257500e+06, 3.24702500e+06, 8.04337000e+05, 5.24749600e+06,
#         1.01572040e+07, 4.35230900e+06, 1.31460200e+06, 1.38686900e+06,
#         2.26591600e+06, 9.36744300e+06, 2.98311600e+06, 2.01611200e+06,
#         1.71776060e+07, 1.44822700e+06, 3.35181900e+06, 2.42843200e+06,
#         9.82908000e+05, 3.02608100e+06, 2.98226500e+06, 6.30886600e+06,
#         1.14088700e+06, 2.32124500e+06, 8.04662000e+05, 2.32334000e+05,
#         3.23044900e+06, 5.54954200e+06, 9.35945200e+06, 8.06861600e+06,
#         3.38119700e+06, 5.57520400e+06, 6.91526700e+06, 7.24474000e+06,
#         2.78945000e+06, 3.48260600e+06, 7.58150000e+04, 4.10443400e+06,
#         1.87385580e+07, 5.32315300e+06, 1.34873700e+06, 2.00387800e+06,
#         7.88231200e+06, 5.57718000e+05, 7.25817800e+06, 6.06573200e+06,
#         3.02277600e+06, 1.74525800e+06, 2.42021400e+06, 4.39829500e+06,
#         5.34400000e+03, 6.08809000e+05, 1.32040100e+06, 2.59962580e+07,
#         5.64051000e+05, 2.26272000e+05, 1.10771450e+07, 4.87916000e+05,
#         3.10622900e+06, 1.50943200e+06, 3.31802700e+06, 4.81423900e+06,
#         5.61225200e+06, 4.46277900e+06, 3.06071200e+06, 3.70052000e+05,
#         3.92670100e+06, 1.66784460e+07, 1.45399000e+06, 1.42014820e+07,
#         4.29651000e+05, 4.97085500e+06, 2.72018300e+06, 1.68235300e+06,
#         1.38962000e+05, 5.89600100e+06, 3.20130500e+06, 1.06839930e+07,
#         2.70612100e+06, 5.21428500e+06, 4.70427900e+06, 1.12546630e+07,
#         1.45917100e+06, 6.81055800e+06, 8.75619000e+05, 7.49446500e+06,
#         5.70824900e+06, 9.75125100e+06, 1.43674600e+06, 9.73116300e+06,
#         2.29080000e+04, 1.14339010e+07, 9.13306200e+06, 6.29826600e+06,
#         2.36450500e+06, 1.36690100e+06, 2.10607500e+06, 6.27120000e+04,
#         7.97072000e+05, 9.81467900e+06, 1.60477560e+07, 2.89455700e+06,
#         5.84562000e+06, 8.66670000e+04, 1.54219310e+07, 4.66167000e+05,
#         4.86421600e+06, 2.31109500e+06, 2.45084600e+06, 7.40208600e+06,
#         4.72590400e+06, 8.44855000e+05, 9.49730200e+06, 3.39868500e+06,
#         5.78286000e+05, 3.73974600e+06, 5.64471700e+06, 9.09524000e+05,
#         9.84340000e+05, 2.64575600e+06, 2.49062280e+07, 8.69271000e+05,
#         7.15737500e+06, 4.01942300e+06, 6.91324000e+05, 4.26864900e+06,
#         4.10159700e+06, 1.98191000e+06, 6.44539500e+06, 9.11195700e+06,
#         6.35613500e+06, 3.61385500e+06, 4.13372000e+06, 2.19201800e+06,
#         1.45552760e+07, 4.57085600e+06, 2.89747300e+06, 7.84259000e+05,
#         2.41539000e+05, 1.41435700e+06, 3.92813600e+06, 1.16760000e+07,
#         7.73539600e+06, 2.72017200e+06, 2.41872900e+06, 2.45516070e+07,
#         5.89755200e+06, 1.00867940e+07, 2.78911000e+06, 5.66613400e+06,
#         8.50575000e+05, 3.15643300e+06, 4.52593600e+06, 1.38553100e+06,
#         3.34361300e+06, 8.66856500e+06, 1.82326800e+06, 3.44483700e+06,
#         7.46869000e+05, 1.20179000e+05, 5.33568700e+06, 3.79144000e+05,
#         7.92924400e+06, 2.29940000e+05, 1.16777700e+06, 6.26257400e+06,
#         4.42527900e+06, 3.26191000e+05, 7.94798000e+05, 6.24942500e+06,
#         6.76683600e+06, 3.78019000e+05, 3.68944400e+06, 5.12595200e+06,
#         1.44119090e+07, 1.46292700e+06, 1.15122300e+07, 1.44553400e+06,
#         1.11206800e+07, 3.31105200e+06, 1.43818700e+06, 9.19260100e+06,
#         4.53700500e+06, 7.03011800e+06, 4.33767300e+06, 4.44500000e+03,
#         2.77710900e+06, 4.04092000e+05, 2.08489700e+06, 1.10535000e+05,
#         4.88543700e+06, 1.38144230e+07, 5.82142080e+07, 7.31337700e+06,
#         4.21091300e+06, 2.24591200e+06, 1.04964400e+06, 1.97631880e+07,
#         3.80318000e+06, 3.64882300e+06, 8.38805400e+06, 1.15654300e+06,
#         1.08852680e+07, 1.19326590e+07, 1.63946400e+06, 3.19243700e+06,
#         1.62933600e+06, 1.58172000e+07, 4.94643300e+06, 1.87168900e+06,
#         8.41243900e+06, 4.37543300e+06, 8.69299300e+06, 2.15646700e+06,
#         2.96955100e+06, 6.39235700e+06, 1.54514700e+07, 4.78048900e+06,
#         5.95276400e+06, 1.73292000e+05, 5.11283653e+08, 3.02196700e+06,
#         5.05853600e+06, 1.74672200e+06, 4.80369900e+06, 1.23711870e+07,
#         8.12050000e+05, 1.70916890e+07, 1.73328000e+06, 2.81561700e+06,
#         5.63396900e+06, 1.22917800e+06, 1.07046930e+07, 3.25084000e+05,
#         1.61584500e+06, 8.66491500e+06, 7.53996300e+06, 1.09150840e+07,
#         7.24779400e+06, 1.37389700e+06, 7.83773700e+06, 1.81692080e+07,
#         1.15478810e+07, 6.80396800e+06, 3.54556100e+06, 9.16375000e+05,
#         1.26412200e+06, 6.12810000e+04, 1.62812282e+08, 1.68884930e+07,
#         8.68440100e+06, 9.48311000e+05, 6.39672000e+05, 1.81426400e+06,
#         1.19922400e+06, 1.09834200e+07, 7.04424500e+06, 8.44574100e+06,
#         1.13096330e+07, 8.15555300e+06, 2.86398600e+06, 4.61303800e+06,
#         4.06127400e+06, 1.35401760e+07, 7.68703000e+05, 1.19069970e+07,
#         7.26438500e+06, 5.90950000e+04, 2.49667610e+07, 9.17715300e+06,
#         4.88489600e+06, 6.63384000e+06, 2.55014700e+06, 1.32465400e+06,
#         1.58193700e+06, 2.72028900e+06, 1.41584420e+07, 1.27114200e+06,
#         2.03142000e+05, 2.96992300e+06, 1.60082540e+07, 2.22245070e+07,
#         8.49684000e+05, 1.37059000e+05, 6.06383200e+06, 3.75015100e+06,
#         2.55372800e+06, 1.50106600e+06, 5.93469000e+06, 8.12224000e+05,
#         4.60070300e+06, 6.07583000e+05, 1.80235000e+05, 1.19680420e+07,
#         6.91507700e+06, 4.44452400e+06, 5.08351500e+06, 6.38407000e+05,
#         2.52965100e+06, 1.78695100e+06, 5.21358700e+06, 3.97822800e+06,
#         9.66200300e+06, 1.08784750e+07, 8.16945100e+06, 1.20178000e+06,
#         2.02978400e+06, 6.70365000e+05, 1.49266800e+06, 6.90417000e+05,
#         2.89159600e+06, 5.42620000e+05, 1.04845590e+07, 5.49822200e+06,
#         6.95280700e+06, 2.79040000e+04, 5.58891000e+05, 8.57110100e+06,
#         1.06833030e+07, 1.00297200e+06, 4.09036500e+06, 9.09721900e+06,
#         2.33077930e+07, 4.23527700e+06, 8.48806100e+06, 9.68125100e+06,
#         2.31662437e+08, 5.57567200e+06, 8.53949000e+05, 5.85209400e+06,
#         6.77042700e+06, 1.29640700e+06, 1.36203000e+06, 3.93454500e+06,
#         2.78825900e+06, 1.68333000e+05, 1.05620500e+06, 4.81179000e+05,
#         7.47920400e+06, 2.04272400e+06, 1.70045600e+06, 1.55886800e+06,
#         4.30746000e+05, 9.54778900e+06, 5.81390800e+06, 1.08755470e+07,
#         1.92026600e+06, 1.14258130e+07, 7.21496700e+06, 2.96794600e+06,
#         7.10433700e+06, 4.40453500e+06, 1.67772500e+06, 1.39472200e+06,
#         1.06644100e+06, 8.06871000e+05, 2.98471200e+06, 3.01407100e+06,
#         6.74837900e+06, 6.41230000e+04, 3.29569600e+06, 2.96519060e+07,
#         8.83511200e+06, 5.87984000e+05, 3.69338014e+08, 6.26173000e+05,
#         1.10673070e+07, 2.72319400e+06, 2.73305200e+06, 4.14530000e+04,
#         1.34795120e+07, 4.62795300e+06, 2.71576100e+06, 2.48204600e+06,
#         2.92442500e+06, 2.94043400e+06, 2.04395000e+05, 7.41078000e+05,
#         7.34202300e+06, 1.67413030e+07, 1.15300400e+06, 8.38873400e+06,
#         4.87202900e+06, 8.65699000e+05, 7.98118800e+06, 2.06378220e+07,
#         3.12345500e+06, 8.21426000e+05, 5.35992600e+06, 2.93271900e+06,
#         1.13359700e+06, 9.05550000e+06, 3.88143300e+06, 2.79902390e+07,
#         3.26542100e+06, 1.04991200e+06, 1.15249280e+07, 9.83732000e+05,
#         1.46857120e+07, 5.61634300e+06, 2.56106000e+05, 5.32530000e+04,
#         4.59344100e+06, 2.03269360e+07, 2.59853500e+06, 1.21979880e+07,
#         3.04221100e+06, 9.74402000e+05, 2.05486380e+07, 1.11781240e+07,
#         4.75384100e+06, 4.70271800e+06, 2.93752020e+07, 7.74709000e+05,
#         1.38553640e+07, 3.32899200e+06, 3.95607300e+06, 7.86891800e+06,
#         5.02015300e+06, 6.89122000e+05, 2.97012000e+06, 1.83196200e+06,
#         2.00559400e+06, 7.37065000e+05, 6.40292000e+05, 4.83841000e+06,
#         1.14597030e+07, 2.75653600e+06, 1.20088900e+06, 1.08968920e+07,
#         8.03167100e+06, 3.81386800e+06, 3.28158100e+06, 9.06689400e+06,
#         2.36724600e+06, 1.71525000e+05, 2.99400500e+06, 4.18491500e+06,
#         6.90043200e+06, 2.36580500e+06, 6.81018500e+06, 3.57750200e+06,
#         6.23983000e+06, 3.84914700e+06, 7.36623100e+06, 1.18138200e+06]])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-4edadf54039e> in <module>
#       4 RUN_MAKE_MH_DF = True
#       5 if RUN_MAKE_MH_DF:
# ----> 6     minhash_exp.run(exp_data, exp_df, hash_vals=hash_vals)
#       7     exp_df.to_csv(mh_csv_file, index=False)
#       8 else:
#
# ~/Desktop/School/DATA606/plagarism/plagiarism_lib/minhash_experiment.py in run(exp_data, exp_df, hash_vals)
#      77         cur_series = []
#      78         for _, row in exp_df.iterrows():
# ---> 79             s = mh.get_similarity(row['doci'], row['docj'])
#      80             cur_series.append(s)
#      81
#
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1069         key = com.apply_if_callable(key, self)
#    1070         try:
# -> 1071             result = self.index.get_value(self, key)
#    1072
#    1073             if not is_scalar(result):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4726         k = com.values_from_object(key)
#    4727
# -> 4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
#    4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in _convert_scalar_indexer(self, key, kind)
#    3104     @Appender(_index_shared_docs["_convert_scalar_indexer"])
#    3105     def _convert_scalar_indexer(self, key, kind=None):
# -> 3106         assert kind in ["ix", "loc", "getitem", "iloc", None]
#    3107
#    3108         if kind == "iloc":
#
# KeyboardInterrupt:

# %% [markdown]
# The following chunk computes the error of minhash similarity estimates. We are going to use that to see what the effect of the number of hashes used in the minhash signature affects the error of the MinHash estimate of Jaccard similarity.

# %%
rmse_df = minhash_exp.post_process_df(exp_df, hash_vals)

# %% [markdown]
# The following chunk plots root mean squared error between minhash JS estimate and exact Jaccard similarity

# %%
# %matplotlib inline

import matplotlib.pyplot as plt


#fig, ax = plt.subplots()
rmse_df.plot(x='h',y='rmse')#, ax=ax)
plt.show()

# %% [markdown]
# **TODO**: Comment on the effect of the number of hashes used in the minhash signature matrix and the error of the MinHash estimate.

# %%
# COMMENT
# As the number of hashes increases, the mean-square-error decreases. However, there are diminishing returns # as you increase the number of hashes used, which is probably a function of the complexity of and number of # documents

# %% [markdown]
# ## Part 3: LSH
#
# Prepare article database for training file, using $k=10$ for shingles

# %%
import plagiarism_lib.lsh_experiment as lsh_exp
from plagiarism_lib.article_db import ArticleDB
from plagiarism_lib.minhash import invert_shingles, MinHash
from pathlib import Path

numdocs = 1000
trainfile = DATA_PATH + '/articles_%d.train' % numdocs

k = 10
print("Preparing Data")
artdb = ArticleDB(trainfile)
inv_data, docids = invert_shingles(artdb.shingle_data(k))

# %% [markdown]
# Compute the minhash signature matrix with 100 rows (hash functions)

# %%
num_hash = 100
mh_mat_file = RESDIR_PATH + '/mh_mat_%d_%d_%d.npy' % (numdocs, k, num_hash)

mh = MinHash(num_hash)
if Path(mh_mat_file).is_file():
    print("Loading MH signature matrix from file")
    mh.from_file(docids, mh_mat_file)
else:
    print("Creating minhash matrix with %d hashes" % num_hash)
    mh.make_matrix((inv_data, docids), inverted=True) 
    mh.save_matrix(mh_mat_file)
# Out:
# Loading MH signature matrix from file

# %% [markdown]
# **TODO**: Finish implementing function `plagiarism_lib.lsh._do_lsh` to implement Locality Sensitive Hashing.
#
# Once that is done, run an experiment of using LSH with desired similarity threshold values to detect plagiarism. Set `RUN_LSH_EXP=True` and run the following chunk.

# %%
import plagiarism_lib.lsh_experiment as lsh_exp

DEFAULT_TS = [.01, .05, .10]#, .30, .50, .70, .90, .95, .99]

truthfile = DATA_PATH + '/articles_%d.truth' % numdocs
lsh_csv_file = RESDIR_PATH + '/lsh_df.csv'

RUN_LSH_EXP = True
if RUN_LSH_EXP:
    exp_df = lsh_exp.run(mh, truthfile, ts=DEFAULT_TS)
    exp_df.to_csv(lsh_csv_file, index=False)
else:
    exp_df = pd.read_csv(lsh_csv_file)
# Out:
# Doing LSH with t= 0.01
# Using 100 bands for 100 rows
#   returned: 2, tp=0.0000, prec=0.0000, rec=0.0000
# Doing LSH with t= 0.05
# Using 71 bands for 100 rows
#   returned: 2, tp=0.0000, prec=0.0000, rec=0.0000
# Doing LSH with t= 0.1
# Using 57 bands for 100 rows
#   returned: 2, tp=0.0000, prec=0.0000, rec=0.0000

# %% [markdown]
# The following chunk plots precision and recall of this system as a function of the LSH threshold chosen.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plot_df = exp_df.melt(id_vars=['t'])

fig, ax = plt.subplots()
labels = []

for key, grp in plot_df.groupby('variable'):
    ax = grp.plot(ax=ax, kind='line', x='t', y='value')
    labels.append(key)
lines, _ = ax.get_legend_handles_labels()
ax.legend(lines, labels, loc='best')
plt.show()

# %% [markdown]
# **TODO**: Comment on the behavior of precision and recall as a function of similarity threshold.

# %%
# COMMENT
# Could not get a curve to display for the above graph, but I speculate that the precision, which is the true positives divied by true positives and false positives, would increase as the similarity threshold increases since there is a tighter tolerance for accepting similar documents, resulting in the documents identified as similar having a high probability of actually being similar. However, the recall may decrease as the similarity threshold increases since due to the tighter tolerance, there would be less documents identified as similar.
